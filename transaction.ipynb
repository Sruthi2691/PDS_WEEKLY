# %%
import pandas as pd
import numpy as np

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\SRUTHI\\Desktop\\Weekly task'

# %%
df = pd.read_csv(r"C:\\Users\\SRUTHI\\Desktop\\Weekly task\transaction.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   TransactionTD  8 non-null      int64
#  1   Category       8 non-null      object
#  2   Amount         8 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 324.0+ bytes

# %%
total_records=len(df)
mean_amount=np.mean(df["Amount"])
variance=np.var(df["Amount"],ddof=1)
maximum=np.max(df["Amount"])
minimum=np.min(df["Amount"])
print("total records:",total_records)
print("mean_amount:",round(mean_amount,2))
print("variance:",round(variance,2))
print("maximum amount:",maximum)
print("minimum amount:",minimum)
# Out:
# total records: 8
# mean_amount: 400.0
# variance: 51428.57
# maximum amount: 800
# minimum amount: 100

# %%
memory=df.memory_usage(deep=True)
print(memory)
print("total memory used:",memory.sum(),"bytes")
# Out:
# Index            132
# TransactionTD     64
# Category         433
# Amount            64
# dtype: int64
# total memory used: 693 bytes

# %%
sample_data = """TransactionTD,Category,Amount
1000,Food,250
1002,Travel,800
1003,Food,300
1004,Shopping,300
1005,Travel,450
1006,Food,100
1007,Bills,650
1008,Food,350
"""
with open("transaction1.csv","w")as file:
    file.write(sample_data)
print("Sample CSV file created successfully.")
# Out:
# Sample CSV file created successfully.

# %%
with open ("transaction1.csv","r")as file:
    print(file.read())
# Out:
# TransactionTD,Category,Amount
# 1000,Food,250
# 1002,Travel,800
# 1003,Food,300
# 1004,Shopping,300
# 1005,Travel,450
# 1006,Food,100
# 1007,Bills,650
# 1008,Food,350

# %%
def parse_csv(filename):
    with open(filename,"r",buffering=8192) as file:
        next(file)
        for line in file:
            line = line.strip()
            if not line:
                continue

            yield line.split(",")

# %%
for row in parse_csv("transaction.csv"):
    print(row)
# Out:
# ['1000', 'Food', '250']
# ['1002', 'Travel', '800']
# ['1003', 'Food', '300']
# ['1004', 'Shopping', '300']
# ['1005', 'Travel', '450']
# ['1006', 'Food', '100']
# ['1007', 'Bills', '650']
# ['1008', 'Food', '350']

# %%
def process_file(filename):
    count = 0
    mean = 0
    M2 = 0

    category_frequency = {}

    for row in parse_csv(filename):
        transaction_id = row[0]
        category = row[1]
        amount = float(row[2])

        count += 1

        # Welford's algorithm for mean and variance
        delta = amount - mean
        mean += delta / count

        delta2 = amount - mean
        M2 += delta * delta2

        # Count frequency of each category
        if category in category_frequency:
            category_frequency[category] += 1
        else:
            category_frequency[category] = 1

    variance = M2 / (count - 1) if count > 1 else 0

    return count, mean, variance, category_frequency

# %%
count, mean, variance, category_frequency = process_file("transaction.csv")

print("Total Records :", count)
print("Running Mean  :", round(mean, 2))
print("Variance      :", round(variance, 2))

print("\nCategory Frequencies")
for category, freq in category_frequency.items():
    print(category, ":", freq)
# Out:
# Total Records : 8
# Running Mean  : 400.0
# Variance      : 51428.57
#
# Category Frequencies
# Food : 4
# Travel : 2
# Shopping : 1
# Bills : 1

# %%
import os
file_size = os.path.getsize("transaction.csv")
print("File Size:", file_size, "bytes")
# Out:
# File Size: 160 bytes
