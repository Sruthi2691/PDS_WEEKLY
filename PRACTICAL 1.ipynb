# %% [markdown]
# # PRACTICAL 1

# %%
#integer
age = 25 
print("Age:", age, "| Type:", type(age)) 
# Float
height = 5.9
print("Height:", height, "| Type:", type(height)) 
# String 
name = "Alice"
print("Name:", name, "| Type:", type(name)) 
# Boolean 
is_student = True
print("Is Student:", is_student, "| Type:", type(is_student)) 
# List
fruits = ["apple", "banana", "cherry"] 
print("Fruits:", fruits, "| Type:", type(fruits))
# Tuple
dimensions = (10, 20)
print("Dimensions:", dimensions, "| Type:", type(dimensions)) 
# Dictionary 
person = {"name": "Bob", "age": 30}
print("Person:", person, "| Type:", type(person)) 
# Set 
unique_numbers = {1, 2, 3, 2}
print("Unique Numbers:", unique_numbers, "| Type:", type(unique_numbers))
# Out:
# Age: 25 | Type: <class 'int'>
# Height: 5.9 | Type: <class 'float'>
# Name: Alice | Type: <class 'str'>
# Is Student: True | Type: <class 'bool'>
# Fruits: ['apple', 'banana', 'cherry'] | Type: <class 'list'>
# Dimensions: (10, 20) | Type: <class 'tuple'>
# Person: {'name': 'Bob', 'age': 30} | Type: <class 'dict'>
# Unique Numbers: {1, 2, 3} | Type: <class 'set'>

# %% [markdown]
# # PRACTICAL 2

# %%
num = int(input("Enter a number: "))
if num > 0:
    print("Positive")
else:
    print("Negative")
n = int(input("Enter another number: "))
if n % 2 == 0:
    print("Even")
else:
    print("Odd")
mark = int(input("Enter mark: "))
if mark >= 90:
    print("Grade A")
elif mark >= 75:
    print("Grade B")
elif mark >= 50:
    print("Grade C")
else:
    print("Fail")
print("For loop:")
for i in range(1, 6):
    print(i)
print("While loop:")
i = 1
while i <= 5:
    print(i)
    i += 1
# Out:
# Enter a number:  5
# Positive
# Enter another number:  8
# Even
# Enter mark:  85
# Grade B
# For loop:
# 1
# 2
# 3
# 4
# 5
# While loop:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# # PRACTICAL 3

# %%
def greet():
    print("Welcome")

def add(a, b):
    return a + b

def square(n):
    return n * n

def factorial(n):
    if n == 0:
        return 1
    return n * factorial(n - 1)

greet()
print("Sum =", add(10, 20))
print("Square =", square(5))
print("Factorial =", factorial(5))
# Out:
# Welcome
# Sum = 30
# Square = 25
# Factorial = 120

# %% [markdown]
# # PRACTICAL 4

# %%
nums = [10, 20, 30, 40, 50]

print("Original List:", nums)

nums.append(60)
nums.insert(2, 25)
nums.remove(40)

print("Updated List:", nums)
print("Length:", len(nums))

square = [x*x for x in nums]
even = [x for x in nums if x % 2 == 0]
odd = [x for x in nums if x % 2 != 0]

print("Squares:", square)
print("Even:", even)
print("Odd:", odd)
# Out:
# Original List: [10, 20, 30, 40, 50]
# Updated List: [10, 20, 25, 30, 50, 60]
# Length: 6
# Squares: [100, 400, 625, 900, 2500, 3600]
# Even: [10, 20, 30, 50, 60]
# Odd: [25]

# %% [markdown]
# # PRACTICAL 5

# %%
t = (10, 20, 30, 40, 50)

print("Tuple:", t)
print("First:", t[0])
print("Last:", t[-1])

s = {10, 20, 30}
print("Set:", s)

s.add(40)
s.remove(20)

print("Updated Set:", s)

s2 = {30, 40, 50}
print("Union:", s | s2)
print("Intersection:", s & s2)
# Out:
# Tuple: (10, 20, 30, 40, 50)
# First: 10
# Last: 50
# Set: {10, 20, 30}
# Updated Set: {40, 10, 30}
# Union: {50, 40, 10, 30}
# Intersection: {40, 30}

# %% [markdown]
# # PRACTICAL 6

# %%
student = {
    "Name": "Sruthi",
    "Age": 17,
    "Dept": "DS and AI",
    "College": "SDNB Vaishnav College"
}

print("Original Dictionary:")
print(student)

# Access values
print("Name:", student["Name"])
print("Department:", student["Dept"])

# Add a new key-value pair
student["City"] = "Chennai"

# Update an existing value
student["Age"] = 18

# Remove a key-value pair
student.pop("City")

# Display length
print("Length:", len(student))

# Display keys
print("Keys:", student.keys())

# Display values
print("Values:", student.values())

# Display items
print("Items:", student.items())

# Traverse the dictionary
print("Dictionary Elements:")
for key, value in student.items():
    print(key, ":", value)

# Check if a key exists
if "Dept" in student:
    print("Department key exists")

# Copy dictionary
student_copy = student.copy()

# Create another dictionary and clear it
d = {"A": 1, "B": 2}
d.clear()

print("Copied Dictionary:", student_copy)
print("Cleared Dictionary:", d)
# Out:
# Original Dictionary:
# {'Name': 'Sruthi', 'Age': 17, 'Dept': 'DS and AI', 'College': 'SDNB Vaishnav College'}
# Name: Sruthi
# Department: DS and AI
# Length: 4
# Keys: dict_keys(['Name', 'Age', 'Dept', 'College'])
# Values: dict_values(['Sruthi', 18, 'DS and AI', 'SDNB Vaishnav College'])
# Items: dict_items([('Name', 'Sruthi'), ('Age', 18), ('Dept', 'DS and AI'), ('College', 'SDNB Vaishnav College')])
# Dictionary Elements:
# Name : Sruthi
# Age : 18
# Dept : DS and AI
# College : SDNB Vaishnav College
# Department key exists
# Copied Dictionary: {'Name': 'Sruthi', 'Age': 18, 'Dept': 'DS and AI', 'College': 'SDNB Vaishnav College'}
# Cleared Dictionary: {}

# %% [markdown]
# # PRACTICAL 7

# %%
# Write
file = open("sample.txt", "w")
file.write("Python Programming\n")
file.write("File Handling Example")
file.close()

# Read
file = open("sample.txt", "r")
print(file.read())
file.close()

# Append
file = open("sample.txt", "a")
file.write("\nWelcome")
file.close()

# Read Again
file = open("sample.txt", "r")
print("\nUpdated File:")
print(file.read())
file.close()
# Out:
# Python Programming
# File Handling Example
#
# Updated File:
# Python Programming
# File Handling Example
# Welcome

# %% [markdown]
# # PRACTICAL 8

# %%
# Numpy Array Operations
import numpy as np

#Creating Numpy Arrays
array1 =np.array([10,20,30,40,50])

array2 =np.array([1,2,3,4,5])

print("Array 1:")
print(array1)

print("\nArray 2:")
print(array2)

# Array Addition
print("\nAddition:")
print(array1 + array2)

# Array Subtraction
print("\nSubtraction:")
print(array1 - array2)

# Array Multiplication
print("\nMultiplication:")c
print(array1 * array2)

# Array Division
print("\nDivision:")
print(array1 / array2)

# Array Indexing
print("\nFirst element of Array1:")
print(array1[0])
# Out:
# Array 1:
# [10 20 30 40 50]
#
# Array 2:
# [1 2 3 4 5]
#
# Addition:
# [11 22 33 44 55]
#
# Subtraction:
# [ 9 18 27 36 45]
#
# Multiplication:
# [ 10  40  90 160 250]
#
# Division:
# [10. 10. 10. 10. 10.]
#
# First element of Array1:
# 10

# %% [markdown]
# # PRACTICAL 9

# %%
import numpy as np

# Create two NumPy arrays
a = np.array([10, 20, 30, 40, 50])
b = np.array([5, 10, 15, 20, 25])

print("Array A:", a)
print("Array B:", b)

# Arithmetic operations
print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)

# Indexing
print("First element of A:", a[0])

# Slicing
print("Sliced elements of A:", a[1:4])

# Reshaping
c = np.array([1, 2, 3, 4, 5, 6])
reshaped = c.reshape(2, 3)

print("Reshaped Array:")
print(reshaped)
print("Shape:", reshaped.shape)
print("Dimension:", reshaped.ndim)
print("Size:", reshaped.size)

# Aggregation operations
print("Sum:", np.sum(a))
print("Mean:", np.mean(a))
print("Maximum:", np.max(a))
print("Minimum:", np.min(a))

# Universal functions
print("Square root:", np.sqrt(a))
print("Exponential:", np.exp(a))

# Sorting
d = np.array([40, 10, 50, 20, 30])
print("Original Array:", d)
print("Sorted Array:", np.sort(d))

# Concatenation
result = np.concatenate((a, b))
print("Concatenated Array:", result)
# Out:
# Array A: [10 20 30 40 50]
# Array B: [ 5 10 15 20 25]
# Addition: [15 30 45 60 75]
# Subtraction: [ 5 10 15 20 25]
# Multiplication: [  50  200  450  800 1250]
# Division: [2. 2. 2. 2. 2.]
# First element of A: 10
# Sliced elements of A: [20 30 40]
# Reshaped Array:
# [[1 2 3]
#  [4 5 6]]
# Shape: (2, 3)
# Dimension: 2
# Size: 6
# Sum: 150
# Mean: 30.0
# Maximum: 50
# Minimum: 10
# Square root: [3.16227766 4.47213595 5.47722558 6.32455532 7.07106781]
# Exponential: [2.20264658e+04 4.85165195e+08 1.06864746e+13 2.35385267e+17
#  5.18470553e+21]
# Original Array: [40 10 50 20 30]
# Sorted Array: [10 20 30 40 50]
# Concatenated Array: [10 20 30 40 50  5 10 15 20 25]

# %% [markdown]
# # PRACTICAL 10

# %%
import numpy as np

# Create a NumPy array
a = np.array([10, 20, 30, 40, 50])

print("Array:", a)

# Sum
print("Sum:", np.sum(a))

# Mean
print("Mean:", np.mean(a))

# Median
print("Median:", np.median(a))

# Standard deviation
print("Standard Deviation:", np.std(a))

# Variance
print("Variance:", np.var(a))

# Minimum and maximum
print("Minimum:", np.min(a))
print("Maximum:", np.max(a))

# Indices of minimum and maximum
print("Index of Minimum:", np.argmin(a))
print("Index of Maximum:", np.argmax(a))

# Range
print("Range:", np.max(a) - np.min(a))

# Percentiles
print("25th Percentile:", np.percentile(a, 25))
print("50th Percentile:", np.percentile(a, 50))
print("75th Percentile:", np.percentile(a, 75))

# Cumulative sum
print("Cumulative Sum:", np.cumsum(a))

# Sorting
print("Sorted Array:", np.sort(a))
# Out:
# Array: [10 20 30 40 50]
# Sum: 150
# Mean: 30.0
# Median: 30.0
# Standard Deviation: 14.142135623730951
# Variance: 200.0
# Minimum: 10
# Maximum: 50
# Index of Minimum: 0
# Index of Maximum: 4
# Range: 40
# 25th Percentile: 20.0
# 50th Percentile: 30.0
# 75th Percentile: 40.0
# Cumulative Sum: [ 10  30  60 100 150]
# Sorted Array: [10 20 30 40 50]

# %% [markdown]
# # PRACTICAL 11

# %%
# Pandas Series and Dataframe OPerations
# !pip install pandas 
import pandas as pd

#...........SERIES...........

#Creating a Series 
series1=pd.Series([10,20,30,40,50])

print("Pandas Series:")
print(series1)

#Accessing Series Elements
print("\nFirst Element:")
print(series1[0])

#Series with Custom Index
series2 =pd.Series(
    [85,90,95],
    index=["Math","Science","English"]
)

print("\nSeries with Custom Index:")
print(series2)

#.............DATAFRAME.............
#Creating Dataframe using Dictionary
student={
    "ID":[101,102,103],
    "Name":["Sakshi","Rahul","Ankit"],
    "Marks":[95,88,90]
}
df =pd.DataFrame(student)

print("\nDataFrame:")
print(df)

#Display First Rows
print("\nFirst Two Rows:")
print(df.head(2))

#Display Last Rows
print("\nLast Two Rows:")
print(df.tail(2))

#Display Column Name
print("\nColumn Name:")
print(df.columns)

#Accessing Single Column
print("\nMarks Columns:")
print(df["Marks"])


#Accessing Multiple Column
print("\nName and Marks Columns:")
print(df[["Name","Marks"]])

#Accessing Rows using loc
print("\nFirst Rows using loc:")
print(df.loc[0]) #work on label
      
#Accessing Rows using iloc
print("\nSecond Rows using iloc:")
print(df.iloc[0]) #work on index

#Adding New Column
df["Grade"] = ["A","B","C"]

print("\nAfter Adding Grade Column:")
print(df)

#Updating Values
df.loc[1,"Marks"] =92

print("\nAfter Updating Marks:")
print(df)

#Deleting Column
df.drop("Grade",axis=1,inplace=True)

print("\nAfter Removing Grade Column:")
print(df)

#Dataframe Information
print("\nDataFrame Information:")
print(df.info())

# Statistical Summary
print("\nStatistical Summary:")
print(df.describe())
# Out:
# ...
# Pandas Series:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
#
# First Element:
# 10
#
# Series with Custom Index:
# Math       85
# Science    90
# English    95
# dtype: int64
#
# DataFrame:
#     ID    Name  Marks
# 0  101  Sakshi     95
# 1  102   Rahul     88
# 2  103   Ankit     90
#
# First Two Rows:
#     ID    Name  Marks
# 0  101  Sakshi     95
# 1  102   Rahul     88
#
# Last Two Rows:
#     ID   Name  Marks
# 1  102  Rahul     88
# 2  103  Ankit     90
#
# Column Name:
# Index(['ID', 'Name', 'Marks'], dtype='object')
#
# Marks Columns:
# 0    95
# 1    88
# 2    90
# Name: Marks, dtype: int64
#
# Name and Marks Columns:
#      Name  Marks
# 0  Sakshi     95
# 1   Rahul     88
# 2   Ankit     90
#
# First Rows using loc:
# ID          101
# Name     Sakshi
# Marks        95
# Name: 0, dtype: object
#
# Second Rows using iloc:
# ID          101
# Name     Sakshi
# Marks        95
# Name: 0, dtype: object
#
# After Adding Grade Column:
# ...

# %% [markdown]
# # PRACTICAL 12

# %%
# PRACTICAL 12 - Handle missing data using pandas

# Step 2: Import libraries
import pandas as pd
import numpy as np

# Step 3: Create a DataFrame containing missing values
data = {
    'Name': ['Amit', 'Priya', None, 'John', 'Sneha'],
    'Age': [20, None, 22, 21, None],
    'Marks': [85, 90, None, 88, 95],
    'City': ['Chennai', 'Mumbai', 'Delhi', None, 'Kolkata']
}
df = pd.DataFrame(data)

# Step 4: Display original DataFrame
print("Original DataFrame:")
print(df)

# Step 5: Check and display missing values using isnull()
print("\nMissing values (True = Missing):")
print(df.isnull())

# Step 6: Count missing values in each column
print("\nNumber of missing values per column:")
print(df.isnull().sum())

# Step 7: Fill all missing values with a default value
print("\nAfter filling all missing with 'Unknown' / 0:")
df_fill_default = df.fillna({'Name':'Unknown', 'Age':0, 'Marks':0, 'City':'Unknown'})
print(df_fill_default)

# Step 8: Fill missing values in Marks column with column mean
mean_marks = df['Marks'].mean()
df['Marks'] = df['Marks'].fillna(mean_marks)
print(f"\nAfter filling Marks with mean ({mean_marks}):")
print(df)

# Step 9: Forward fill
print("\nForward Fill (ffill):")
print(df.ffill())

# Step 10: Backward fill
print("\nBackward Fill (bfill):")
print(df.bfill())

# Step 11: Remove rows containing missing values using dropna()
print("\nAfter dropping rows with missing values (dropna):")
print(df.dropna())

# Step 12: Replace a specified value using replace()
print("\nAfter replacing 'Chennai' with 'CBE' using replace():")
df_replaced = df.replace('Chennai', 'CBE')
print(df_replaced)

# Step 13: Display DataFrame information using info()
print("\nDataFrame Info:")
df.info()

# Step 14: End
print("\nProgram Ended")
# Out:
# Original DataFrame:
#     Name   Age  Marks     City
# 0   Amit  20.0   85.0  Chennai
# 1  Priya   NaN   90.0   Mumbai
# 2   None  22.0    NaN    Delhi
# 3   John  21.0   88.0     None
# 4  Sneha   NaN   95.0  Kolkata
#
# Missing values (True = Missing):
#     Name    Age  Marks   City
# 0  False  False  False  False
# 1  False   True  False  False
# 2   True  False   True  False
# 3  False  False  False   True
# 4  False   True  False  False
#
# Number of missing values per column:
# Name     1
# Age      2
# Marks    1
# City     1
# dtype: int64
#
# After filling all missing with 'Unknown' / 0:
#       Name   Age  Marks     City
# 0     Amit  20.0   85.0  Chennai
# 1    Priya   0.0   90.0   Mumbai
# 2  Unknown  22.0    0.0    Delhi
# 3     John  21.0   88.0  Unknown
# 4    Sneha   0.0   95.0  Kolkata
#
# After filling Marks with mean (89.5):
#     Name   Age  Marks     City
# 0   Amit  20.0   85.0  Chennai
# 1  Priya   NaN   90.0   Mumbai
# 2   None  22.0   89.5    Delhi
# ...

# %% [markdown]
# # PRACTICAL 13

# %%
# PRACTICAL 13 Write a Python program to group and aggregate data in pandas

# Step 2: Import Pandas library
import pandas as pd

# Step 3: Create a DataFrame containing employee details
data = {
    "Department": ["HR", "IT", "HR", "IT", "Sales", "Sales"],
    "Employee": ["Amit", "Rahul", "Priya", "Ankit", "Sakshi", "Riya"],
    "Salary": [30000, 50000, 35000, 60000, 45000, 40000],
    "Experience": [2, 5, 3, 6, 4, 2]
}
df = pd.DataFrame(data)

# Step 4: Display the original DataFrame
print("Original DataFrame:")
print(df)

# Step 5: Group the data based on Department column using groupby()
grouped = df.groupby("Department")

# Step 6: Calculate and display the total salary for each department
print("\nTotal salary for each department:")
print(grouped["Salary"].sum())

# Step 7: Calculate and display the average salary for each department
print("\nAverage salary for each department:")
print(grouped["Salary"].mean())

# Step 8: Find and display the maximum and minimum salary in each department
print("\nMaximum salary in each department:")
print(grouped["Salary"].max())
print("\nMinimum salary in each department:")
print(grouped["Salary"].min())

# Step 9: Count and display the number of employees in each department
print("\nNumber of employees in each department:")
print(grouped["Employee"].count())

# Step 10: Perform multiple aggregation operations (sum, mean, max, and min)
print("\nMultiple aggregation operations on salary column:")
print(grouped["Salary"].agg(['sum', 'mean', 'max', 'min']))

# Step 11: Group the data using both Department and Experience columns
print("\nGroup by Department and Experience and display aggregated salary:")
print(df.groupby(["Department", "Experience"])["Salary"].sum())

# Step 12: Iterate through each group and display the grouped records
print("\nIterate through each group:")
for name, group in grouped:
    print(f"\nDepartment: {name}")
    print(group)

# Step 13: Sort the DataFrame by the Salary column and display the sorted data
print("\n13. DataFrame sorted by Salary:")
print(df.sort_values(by="Salary"))

# Step 14: End the program
print("\nProgram Ended")
# Out:
# Original DataFrame:
#   Department Employee  Salary  Experience
# 0         HR     Amit   30000           2
# 1         IT    Rahul   50000           5
# 2         HR    Priya   35000           3
# 3         IT    Ankit   60000           6
# 4      Sales   Sakshi   45000           4
# 5      Sales     Riya   40000           2
#
# Total salary for each department:
# Department
# HR        65000
# IT       110000
# Sales     85000
# Name: Salary, dtype: int64
#
# Average salary for each department:
# Department
# HR       32500.0
# IT       55000.0
# Sales    42500.0
# Name: Salary, dtype: float64
#
# Maximum salary in each department:
# Department
# HR       35000
# IT       60000
# Sales    45000
# Name: Salary, dtype: int64
#
# Minimum salary in each department:
# Department
# HR       30000
# IT       50000
# Sales    40000
# Name: Salary, dtype: int64
#
# Number of employees in each department:
# Department
# HR       2
# IT       2
# Sales    2
# Name: Employee, dtype: int64
#
# ...

# %% [markdown]
# # PRACTICAL 14

# %%
# Merge and Join DataFrames using Pandas

import pandas as pd

# ----- CONCATENATE OPERATIONS ------------------- (all columns name should be same)

# Creating First DataFrame
df1 = pd.DataFrame({
    "ID": [101, 102, 103, 105],
    "Marks": [95, 88, 90, 85]
}, index=[0, 1, 2, 3])   

print("\nDataFrame 1:")
print(df1)

#  Creating Second DataFrame
df2 = pd.DataFrame({
    "ID": [201, 202, 203, 205],
    "Marks": [85, 78, 80, 65]
}, index=[4, 5, 6, 7])   

print("\nDataFrame 2:")
print(df2)

frames = [df1,df2]
result = pd.concat(frames)
print("concatenate dataframes")
print(result)

# ---------------- MERGE OPERATIONS ---------------- ( at least one column should be same, others can be different  )

# Creating First DataFrame
df1 = pd.DataFrame({
    "ID": [101, 102, 103, 104],
    "Name": ["Sakshi", "Rahul", "Ankit", "Priya"]
})

print("DataFrame 1:")
print(df1)

# Creating Second DataFrame
df2 = pd.DataFrame({
    "ID": [101, 102, 103, 105],
    "Marks": [95, 88, 90, 85]
}, index=[0, 1, 2, 3])   

print("\nDataFrame 2:")
print(df2)

# Inner Merge
inner_merge = pd.merge(df1, df2, on="ID", how="inner")

print("\nInner Merge:")
print(inner_merge)

# Left Merge
left_merge = pd.merge(df1, df2, on="ID", how="left")

print("\nLeft Merge:")
print(left_merge)

# Right Merge
right_merge = pd.merge(df1, df2, on="ID", how="right")

print("\nRight Merge:")
print(right_merge)

# Outer Merge
outer_merge = pd.merge(df1, df2, on="ID", how="outer")

print("\nOuter Merge:")
print(outer_merge)

# ---------------- JOIN OPERATIONS ---------------- ( columns names in both datframes is different )

# Creating DataFrames for Join
df3 = pd.DataFrame({
    "Name": ["Amit", "Riya", "Karan"]
}, index=[1, 2, 3])

df4 = pd.DataFrame({
    "Salary": [30000, 40000, 50000]
}, index=[1, 2, 3])

print("\nDataFrame 3:")
print(df3)

print("\nDataFrame 4:")
print(df4)

# Joining DataFrames
joined_df = df3.join(df4)

print("\nJoined DataFrame:")
print(joined_df)

# Joining with Different Join Types
left_join = df3.join(df4, how="left")

print("\nLeft Join:")
print(left_join)

right_join = df3.join(df4, how="right")

print("\nRight Join:")
print(right_join)

outer_join = df3.join(df4, how="outer")

print("\nOuter Join:")
print(outer_join)
# Out:
# DataFrame 1:
#     ID  Marks
# 0  101     95
# 1  102     88
# 2  103     90
# 3  105     85
#
# DataFrame 2:
#     ID  Marks
# 4  201     85
# 5  202     78
# 6  203     80
# 7  205     65
# concatenate dataframes
#     ID  Marks
# 0  101     95
# 1  102     88
# 2  103     90
# 3  105     85
# 4  201     85
# 5  202     78
# 6  203     80
# 7  205     65
# DataFrame 1:
#     ID    Name
# 0  101  Sakshi
# 1  102   Rahul
# 2  103   Ankit
# 3  104   Priya
#
# DataFrame 2:
#     ID  Marks
# 0  101     95
# 1  102     88
# 2  103     90
# 3  105     85
#
# Inner Merge:
#     ID    Name  Marks
# 0  101  Sakshi     95
# 1  102   Rahul     88
# 2  103   Ankit     90
#
# Left Merge:
#     ID    Name  Marks
# 0  101  Sakshi   95.0
# 1  102   Rahul   88.0
# 2  103   Ankit   90.0
# 3  104   Priya    NaN
#
# Right Merge:
#     ID    Name  Marks
# 0  101  Sakshi     95
# 1  102   Rahul     88
# 2  103   Ankit     90
# 3  105     NaN     85
#
# Outer Merge:
#     ID    Name  Marks
# ...

# %% [markdown]
# # PRACTICAL 15

# %%
# Simple Plots using Matplotlib

import matplotlib.pyplot as plt

#------------------LINE PLOT-----------------

x=[1, 2, 3, 4, 5]
y=[10, 20, 30, 40, 50]

plt.figure(figsize=(5, 4))

plt.plot(x, y)

plt.title("Line Plot")
plt.xlabel("x Values")
plt.ylabel("y values")

plt.show()

#---------------------BAR GRAPH------------------

students = ["A", "B", "C", "D"]
marks = [85, 99, 75, 88]

plt.figure(figsize=(5, 4))

plt.bar(students, marks)

plt.title("BAR Graph")
plt.xlabel("Students")
plt.ylabel("Marks")

plt.show()

#-------------------HISTOGRAM------------------

data =[10, 20, 20, 30, 30, 30, 40, 50, 50]

plt.figure(figsize=(5, 4))

plt.hist(data, bins=5)

plt.title("HISTOGRAM")
plt.xlabel("values")
plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# # PRACTICAL 16

# %%
import matplotlib.pyplot as plt

# ----------------- SCATTER PLOT -----------------

x = [1, 2, 3, 4, 5]
y = [10, 25, 30, 45, 50]

plt.figure(figsize=(5, 4))

plt.scatter(x, y)

plt.title("Scatter Plot")
plt.xlabel("X Values")
plt.ylabel("Y Values")

plt.show()

#------------------SUBPLOTS----------------

x1 =[1, 2, 3, 4]
y1 =[10, 20, 30, 40]

x2 =[1, 2, 3, 4]
y2 =[40, 30, 20, 10]

plt.figure(figsize=(8, 4))

#First Subplot
plt.subplot(1, 2, 1)
plt.plot(x1, y1)
plt.title("Line Plot")

# Second Subplot
plt.subplot(1, 2, 2)
plt.bar(x2, y2)
plt.title("Bar Graph")
plt.tight_layout()

plt.show()

# %% [markdown]
# # PRACTICAL 17

# %%
import pandas as pd
import csv

# Loading CSV File
file_path = r"C:\Users\Saksh\OneDrive\Desktop\SDNB\Python_with_DS\students.csv"


# 1. Load the CSV dataset
#df = pd.read_csv(file_path)
df = pd.read_csv(file_path, sep=",", quoting=csv.QUOTE_NONE)

# 2. Display complete dataset
print("========== COMPLETE DATASET ==========")
print(df)

# 3. Display first 5 rows
print("\n========== FIRST 5 ROWS ==========")
print(df.head())

# 4. Display last 5 rows
print("\n========== LAST 5 ROWS ==========")
print(df.tail())

# 5. Display number of rows and columns
print("\n========== DATASET SHAPE ==========")
print(df.shape)

# 6. Display column names
print("\n========== COLUMN NAMES ==========")
print(df.columns)

# 7. Display data types
print("\n========== DATA TYPES ==========")
print(df.dtypes)

# 8. Display dataset information
print("\n========== DATASET INFORMATION ==========")
df.info()

# 9. Display statistical summary
print("\n========== STATISTICAL SUMMARY ==========")
print(df.describe())

# 10. Check missing values
print("\n========== MISSING VALUES ==========")
print(df.isnull().sum())

# 11. Display a specific column
print("\n========== MARKS COLUMN ==========")
print(df["Marks"])

# 12. Filter students with marks greater than 80
print("\n========== STUDENTS WITH MARKS > 80 ==========")
print(df[df["Marks"] > 80])

# 13. Sort dataset by Marks
print("\n========== DATA SORTED BY MARKS ==========")
print(df.sort_values(by="Marks"))

# 14. Calculate average marks by department
print("\n========== AVERAGE MARKS BY DEPARTMENT ==========")
print(df.groupby("Department")["Marks"].mean())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 10
#       5 file_path = r"C:\Users\Saksh\OneDrive\Desktop\SDNB\Python_with_DS\students.csv"
#       8 # 1. Load the CSV dataset
#       9 #df = pd.read_csv(file_path)
# ---> 10 df = pd.read_csv(file_path, sep=",", quoting=csv.QUOTE_NONE)
#      12 # 2. Display complete dataset
#      13 print("========== COMPLETE DATASET ==========")
#
# ...

# %% [markdown]
# # PRACTICAL 20

# %%
# Data Visualization using Seaborn

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Creating Sample Dataset
data = {
    "Maths": [85, 90, 78, 92, 88],
    "Science": [80, 85, 75, 95, 89],
    "English": [78, 83, 72, 90, 84]
}

# Creating DataFrame
df = pd.DataFrame(data)

print("Dataset:")
print(df)

# -------------------- HEATMAP --------------------
sns.heatmap(df, annot=True, cmap="coolwarm")

plt.title("Student Marks Heatmap")
plt.show()

#-----------------BOXPLOT----------------
plt.figure(figsize=(5, 4))
sns.boxplot(data=df)
plt.title("Boxplot")
plt.show()

#-----------------PAIRPLOT---------------

sns.pairplot(df)
plt.show()
# Out:
# Dataset:
#    Maths  Science  English
# 0     85       80       78
# 1     90       85       83
# 2     78       75       72
# 3     92       95       90
# 4     88       89       84
